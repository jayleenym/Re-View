# %%
import streamlit as st
import pandas as pd
from PIL import Image

# from transformers import BartTokenizer, TFBartForConditionalGeneration, BartConfig
# import tokenizers
from models import *

global DATA_URL
global DATA
global PRODUCT_NAME

DATA_URL = "./"

@st.cache()
def load_data():
    data = pd.read_csv("./labeling_합본.csv")
    data = data[data['표준편차'] < 1][['평균', '상품명', '리뷰']]
    return data

DATA = load_data()
PRODUCT_NAME = DATA['상품명'].unique()

# def images():
#     # 라벨링된 상품 이미지 보여주기
#     st.write("유용성 평가를 할 수 있는 상품 목록입니다")
#     IMAGE_PATH = "../images/"
#     # col1, col2, col3, col4 = st.columns(4)
#     # with col1:
#         st.image(Image.open("../images/라운드랩 자작나무 수분 크림 1+1.jpg"), use_column_width=True)
#         st.radio("", (DATA['상품명'].unique()[0], ""))
#         st.image(Image.open("../images/라운드랩 자작나무 수분 크림 1+1.jpg"), caption = PRODUCT_NAME[0])
#     with col2:
#         st.image(Image.open("../images/라운드랩 자작나무 수분 크림 1+1.jpg"), caption= DATA['상품명'].unique()[0])

#     with col3:
#         st.image(Image.open("../images/라운드랩 자작나무 수분 크림 1+1.jpg"), caption= DATA['상품명'].unique()[0])

#     with col4: st.image(Image.open("../images/라운드랩 자작나무 수분 크림 1+1.jpg"), caption= DATA['상품명'].unique()[0])

def product():
    pro = st.radio("리뷰 분석이 가능한 상품 목록입니다", (PRODUCT_NAME))
    for i in range(len(PRODUCT_NAME)):
        if pro == PRODUCT_NAME[i]:
            st.image(Image.open(f"../images/{i}.jpg"), width = 300) #, caption = PRODUCT_NAME[0]) 
            
    



def main():
    selected_box = st.sidebar.selectbox(
    'Choose one of the following', ('Home', PRODUCT_NAME[0]) 
    )

    if selected_box == "Home" :
        st.title("✍🏻리뷰의 반란")
        st.subheader("안녕하세요, 🧠무뇌형 인간🧠입니다")
        
         
        #  st.write(DATA)

    if selected_box == '상품 보기': product()
        
    
if __name__ == "__main__":
    main()
# Out:
# 2022-01-09 11:21:14.836
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/homebrew/lib/python3.9/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# /var/folders/4_/c_rvl_fj5w95qbghxb859jg80000gn/T/ipykernel_1222/3802996886.py in <module>
#      19     return data
#      20
# ---> 21 DATA = load_data()
#      22 PRODUCT_NAME = DATA['상품명'].unique()
#      23
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     572         if show_spinner:
#     573             with st.spinner(message):
# --> 574                 return get_or_create_cached_value()
#     575         else:
#     576             return get_or_create_cached_value()
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/caching.py in get_or_create_cached_value()
#     497                 # If we generated the key earlier we would only hash those
#     498                 # globals by name, and miss changes in their code or value.
# --> 499                 cache_key = _hash_func(func, hash_funcs)
#     500
#     501             # First, get the cache that's attached to this function.
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     623     # because this step will be hashing any objects referenced in the function
#     624     # body.
# --> 625     update_hash(
#     626         func,
#     627         hasher=func_hasher,
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     114
#     115     ch = _CodeHasher(hash_funcs)
# --> 116     ch.update(hasher, val, context)
#     117
#     118
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     391     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     392         """Update the provided hasher with the hash of an object."""
# --> 393         b = self.to_bytes(obj, context)
#     394         hasher.update(b)
#     395
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     380
#     381         except BaseException as e:
# --> 382             raise InternalHashError(e, obj)
#     383
#     384         finally:
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     366         try:
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#     370             # Hmmm... It's possible that the size calculation is wrong. When we
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     632             code = getattr(obj, "__code__", None)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#     636                 defaults = getattr(obj, "__defaults__", None)
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     408             return False
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#     412
#
# /opt/homebrew/lib/python3.9/site-packages/streamlit/legacy_caching/hashing.py in _get_main_script_directory()
#     719         # This works because we set __main__.__file__ to the report
#     720         # script path in ScriptRunner.
# --> 721         main_path = __main__.__file__
#     722         return str(os.path.dirname(main_path))
#     723
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x129324430>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
pd.read_csv('./labeling_합본.csv')
# Out:
#      문예진  이상민  정수연  정승연  황의린   평균      표준편차  \
# 0      5    5    5    5    5  5.0  0.000000
# 1      5    5    5    5    5  5.0  0.000000
# 2      4    5    5    5    4  4.6  0.547723
# 3      3    4    4    4    4  3.8  0.447214
# 4      3    5    4    4    4  4.0  0.707107
# ..   ...  ...  ...  ...  ...  ...       ...
# 495    2    2    3    3    3  2.6  0.547723
# 496    3    2    2    3    3  2.6  0.547723
# 497    2    2    2    2    2  2.0  0.000000
# 498    3    2    3    3    3  2.8  0.447214
# 499    2    3    3    3    3  2.8  0.447214
#
#                                           상품명  \
# 0    ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 1    ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 2    ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 3    ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 4    ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# ..                                        ...
# 495  ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 496  ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 497  ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 498  ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
# 499  ★에바 P!CK★라운드랩 자작나무 수분크림 1+1기획(+수분패드 10매)
#
#                                                     리뷰  index
# 0    이브랜드는 올리브영 입점전부터 써본브랜드입니다\n 수분크림구매시에 성분이 중요한데요...      0
# 1    전에 어찌어찌하다 자작나무 수분크림 샘플을 받아 잘 쓰고 있는 중에\n 1+1행사한...      1
# 2    올리브영 대표 클린뷰티! 라운드랩!\n \n # 라운드랩 자작나무 수분 크림 \n ...      2
# 3    💚수분감\n 진짜 내가 찾던 수분만 있는 제품.. 유분은 기름종이 보시면 알겠지만 ...      3
# 4    원쁠원 행사 넘 좋아요 이번달 끝나기 전에 하나 더 사놓을까 고민이 되네요 .. ❄...      4
# ..                                                 ...    ...
# 495  아토피도 있고 피부가 민감한 편인데 한번만 써봐도 진짜 순하다는 게 느껴져요. 요즘...    495
# 496  예민한 피부에도 사용 가능할 정도로 유해 성분 없이 순하다. 보습력이 강해 건성에게...    496
# 497     촉촉하고 여름에 지성피부가 쓰기 딱이에요 팩처럼 듬뿍 올려놓고 자면 진정에 최곱니당    497
# 498  처음 발랐을땐 되게 빨리 흡수되서 금방 건조해지는거 아닌가싶었는데 속당김 없고 보습...    498
# 499  처음에는 크림 롤링할때 알갱이가 느껴져서 이게 뭔가 싶었는데 계속 문대니 금새 사라...    499
#
# [500 rows x 10 columns]
